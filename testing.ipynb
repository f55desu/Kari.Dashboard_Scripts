# %%
# !pip install playwright pytest-playwright
# Out:
# Collecting playwright
#   Downloading playwright-1.58.0-py3-none-win_amd64.whl (36.8 MB)
#      --------------------------------------- 36.8/36.8 MB 26.2 MB/s eta 0:00:00
# Collecting pytest-playwright
#   Downloading pytest_playwright-0.7.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in c:\users\i.taldykin\appdata\local\programs\python\python310\lib\site-packages (from playwright) (3.2.4)
# Collecting pyee<14,>=13
#   Downloading pyee-13.0.1-py3-none-any.whl (15 kB)
# Collecting pytest<10.0.0,>=6.2.4
#   Downloading pytest-9.0.2-py3-none-any.whl (374 kB)
#      ------------------------------------- 374.8/374.8 kB 22.8 MB/s eta 0:00:00
# Collecting python-slugify<9.0.0,>=6.0.0
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Collecting pytest-base-url<3.0.0,>=1.0.0
#   Downloading pytest_base_url-2.1.0-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: typing-extensions in c:\users\i.taldykin\appdata\local\programs\python\python310\lib\site-packages (from pyee<14,>=13->playwright) (4.14.1)
# Requirement already satisfied: colorama>=0.4 in c:\users\i.taldykin\appdata\roaming\python\python310\site-packages (from pytest<10.0.0,>=6.2.4->pytest-playwright) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1 in c:\users\i.taldykin\appdata\roaming\python\python310\site-packages (from pytest<10.0.0,>=6.2.4->pytest-playwright) (1.3.0)
# Collecting pluggy<2,>=1.5
#   Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: packaging>=22 in c:\users\i.taldykin\appdata\roaming\python\python310\site-packages (from pytest<10.0.0,>=6.2.4->pytest-playwright) (25.0)
# Collecting tomli>=1
#   Downloading tomli-2.4.1-py3-none-any.whl (14 kB)
# Collecting iniconfig>=1.0.1
#   Downloading iniconfig-2.3.0-py3-none-any.whl (7.5 kB)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\i.taldykin\appdata\roaming\python\python310\site-packages (from pytest<10.0.0,>=6.2.4->pytest-playwright) (2.19.2)
# Requirement already satisfied: requests>=2.9 in c:\users\i.taldykin\appdata\local\programs\python\python310\lib\site-packages (from pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (2.32.5)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.2/78.2 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\i.taldykin\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\i.taldykin\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\i.taldykin\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (3.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\i.taldykin\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (2025.10.5)
# Installing collected packages: text-unidecode, tomli, python-slugify, pyee, pluggy, iniconfig, pytest, playwright, pytest-base-url, pytest-playwright
# Successfully installed iniconfig-2.3.0 playwright-1.58.0 pluggy-1.6.0 pyee-13.0.1 pytest-9.0.2 pytest-base-url-2.1.0 pytest-playwright-0.7.2 python-slugify-8.0.4 text-unidecode-1.3 tomli-2.4.1
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
import pyodbc
import win32com.client as win32
import time  # Для измерения времени выполнения
import shutil
import re
# import pyarrow as pa
# import pyarrow.csv as csv


FOLDER_PATH = os.path.normpath(r"\\kari.local\public\all\Analytics\Marketplaceanalytics\Федоров\Дашбоард по рекламным кампаниям\!!!_ИСХОДНИКИ ДЛЯ ДАШБОРДА_НЕ УДАЛЯТЬ_!!!")
# Сохранение финальной таблицы
df = pd.read_csv(os.path.join(FOLDER_PATH, "ДБсПризнаками_Test.csv"))
# df = pd.read_csv(os.path.join(FOLDER_PATH, "ДБсПризнаками.csv"))
# print(df.head(20))
# print(df.columns)
# Out:
# C:\Users\i.taldykin\AppData\Local\Temp\ipykernel_7448\3811412687.py:15: DtypeWarning: Columns (69) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(FOLDER_PATH, "ДБсПризнаками_Test.csv"))

# %%
print(list(df.columns))
# Out:
# ['Дата', 'Артикул WB', 'Рейтинг карточки товара', 'Количество показов товара', 'Просмотры карточки товара', 'Добавлений в корзину', 'Количество заказов', 'Количество выкупов', 'Количество отмен', 'Сумма заказов', 'Сумма выкупов', 'Сумма отмен', 'Средняя цена продажи', 'Рейтинг по отзывам', 'Единая Ставка — Расходы на рекламу', 'Единая Ставка — Количество рекламных заказов', 'Единая Ставка — Добавлений в корзину от рекламы', 'Единая Ставка — Количество товаров в рекламных заказах', 'Единая Ставка — Сумма рекламных заказов', 'Единая Ставка — Количество кликов по рекламе', 'Единая Ставка — Количество рекламных показов', 'Ручная Ставка — Расходы на рекламу', 'Ручная Ставка — Количество рекламных заказов', 'Ручная Ставка — Добавлений в корзину от рекламы', 'Ручная Ставка — Количество товаров в рекламных заказах', 'Ручная Ставка — Сумма рекламных заказов', 'Ручная Ставка — Количество кликов по рекламе', 'Ручная Ставка — Количество рекламных показов', 'Количество рекламных показов', 'Сумма рекламных заказов', 'Количество рекламных заказов', 'Количество кликов по рекламе', 'Добавлений в корзину от рекламы', 'Количество товаров в рекламных заказах', 'Расходы на рекламу', 'Признак автоматической рекламной кампании', 'Признак аукционной рекламной кампании', 'Признак органического трафика', 'Тип рекламной активности', 'Единая Ставка — Идентификатор рекламной кампании', 'Ручная Ставка — Идентификатор рекламной кампании', 'Артикул', 'Название товара', 'Коллекция', 'Бренд', 'Сезон', 'Направление', 'Розничный отдел', 'Модель', 'Товарная группа', 'Бизнес-группа', 'Технологический сегмент', 'Байер', 'Две последние коллекции', 'Основной артикул', 'Себестоимость товара с НДС', 'Процент выкупа на Wildberries', 'Ставка НДС', 'Ответственный за товарную группу', 'Группа для отчётов', 'Розничная цена товара', 'Остаток товара на складе агрегатора', 'Дистрибуция размеров', 'Количество показов по выгрузке', 'Количество кликов по выгрузке', 'Добавлений в корзину по выгрузке', 'Количество заказов по выгрузке', 'Признак товара 1', 'Признак товара 2', 'Признак товара 3', 'Признак товара 4', 'Признак товара 5', 'Признак даты 1', 'Признак даты 2', 'Признак даты 3', 'Признак даты 4', 'Признак даты 5', 'Идентификатор текущей склейки товара', 'Идентификатор рекламной кампании', 'Количество ассоциированных заказов', 'Сумма ассоциированных заказов']

# %%
df['ТипАктивности'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\i.taldykin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ТипАктивности'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df['ТипАктивности'].value_counts()
#
# File c:\Users\i.taldykin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\i.taldykin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'ТипАктивности'

# %%
df['Цена'].unique()
# Out:
# array([ 1298.,  2199.,  1445., ...,  7644.,  9610., 10624.],
#       shape=(12062,))

# %%
df['Дата'].unique()
# Out:
# array(['01.04.2026', '01.05.2026', '02.04.2026', '02.05.2026',
#        '03.04.2026', '03.05.2026', '04.04.2026', '04.05.2026',
#        '05.04.2026', '05.05.2026', '06.04.2026', '06.05.2026',
#        '07.04.2026', '07.05.2026', '08.04.2026', '08.05.2026',
#        '09.04.2026', '09.05.2026', '10.04.2026', '10.05.2026',
#        '11.04.2026', '11.05.2026', '12.04.2026', '12.05.2026',
#        '13.04.2026', '13.05.2026', '14.04.2026', '14.05.2026',
#        '15.04.2026', '15.05.2026', '16.04.2026', '16.05.2026',
#        '17.04.2026', '17.05.2026', '18.04.2026', '19.04.2026',
#        '20.04.2026', '21.04.2026', '22.04.2026', '23.04.2026',
#        '24.04.2026', '25.04.2026', '26.04.2026', '27.04.2026',
#        '28.04.2026', '29.04.2026', '30.03.2026', '30.04.2026',
#        '31.03.2026'], dtype=object)

# %%
df
# Out:
#                Дата   Артикул    Артикул OZ                Наименование  \
# 0        2025-09-01  00006020  1.493938e+08     Балетки женские 298-9CK
# 1        2025-09-01  00006050  1.493909e+08   Балетки женские ZS1810-1K
# 2        2025-09-01  00006060  1.493910e+08    Балетки женские ZS183-2K
# 3        2025-09-01  00006080  1.493909e+08    Балетки женские ZS189-7K
# 4        2025-09-01  000060H0  1.493724e+08  Балетки женские K0346PM-1A
# ...             ...       ...           ...                         ...
# 3797039  2025-11-16  y9808110  1.997932e+09     Шорты мужские  A85512-2
# 3797040  2025-11-16  y9808120  1.997933e+09     Шорты мужские  A85512-3
# 3797041  2025-11-16  y9808130  1.934644e+09     Шорты мужские SS25C2020
# 3797042  2025-11-16  y9808140  1.950209e+09     Шорты мужские SS25C2021
# 3797043  2025-11-16  y9808150  1.950209e+09     Шорты мужские SS25C2022
#
#         Коллекция          Бренд            Сезон        Направление  \
# 0          2019SS     T.TACCARDI  лето (закрытое)      Женская обувь
# 1          2019SS     T.TACCARDI  лето (закрытое)      Женская обувь
# 2          2019SS     T.TACCARDI  лето (закрытое)      Женская обувь
# 3          2019SS     T.TACCARDI  лето (закрытое)      Женская обувь
# 4          2019SS  PIERRE CARDIN  лето (закрытое)      Женская обувь
# ...           ...            ...              ...                ...
# 3797039    2025SS           kari      всесезонный  Одежда для мужчин
# 3797040    2025SS           kari      всесезонный  Одежда для мужчин
# 3797041    2025SS           kari      весна, лето  Одежда для мужчин
# 3797042    2025SS           kari      весна, лето  Одежда для мужчин
# 3797043    2025SS           kari      весна, лето  Одежда для мужчин
#
#                       Розничный отдел      Модель  ... Признак Артикула 2  \
# 0                       Женская обувь     298-9CK  ...                NaN
# 1                       Женская обувь   ZS1810-1K  ...                NaN
# 2                       Женская обувь    ZS183-2K  ...                NaN
# 3                       Женская обувь    ZS189-7K  ...                NaN
# 4                       Женская обувь  K0346PM-1A  ...                NaN
# ...                               ...         ...  ...                ...
# 3797039  Спортивная одежда для мужчин    A85512-2  ...                NaN
# 3797040  Спортивная одежда для мужчин    A85512-3  ...                NaN
# 3797041          Брюки, шорты мужские   SS25C2020  ...                NaN
# 3797042          Брюки, шорты мужские   SS25C2021  ...                NaN
# 3797043          Брюки, шорты мужские   SS25C2022  ...                NaN
#
#         Признак Артикула 3 Признак Артикула 4 Признак Артикула 5  \
# 0                      NaN                NaN                NaN
# 1                      NaN                NaN                NaN
# 2                      NaN                NaN                NaN
# 3                      NaN                NaN                NaN
# 4                      NaN                NaN                NaN
# ...                    ...                ...                ...
# 3797039                NaN                NaN                NaN
# 3797040                NaN                NaN                NaN
# 3797041                NaN                NaN                NaN
# 3797042                NaN                NaN                NaN
# 3797043                NaN                NaN                NaN
#
#         Признак Даты 1 Признак Даты 2  Признак Даты 3  Признак Даты 4  \
# 0                  NaN            NaN             NaN             NaN
# 1                  NaN            NaN             NaN             NaN
# 2                  NaN            NaN             NaN             NaN
# 3                  NaN            NaN             NaN             NaN
# 4                  NaN            NaN             NaN             NaN
# ...                ...            ...             ...             ...
# 3797039            NaN            NaN             NaN             NaN
# 3797040            NaN            NaN             NaN             NaN
# 3797041            NaN            NaN             NaN             NaN
# 3797042            NaN            NaN             NaN             NaN
# 3797043            NaN            NaN             NaN             NaN
#
#          Признак Даты 5 ТипАктивности
# 0                   NaN      Органика
# 1                   NaN      Органика
# 2                   NaN      Органика
# 3                   NaN      Органика
# 4                   NaN      Органика
# ...                 ...           ...
# 3797039             NaN      Органика
# 3797040             NaN      Органика
# 3797041             NaN      Органика
# 3797042             NaN      Органика
# 3797043             NaN      Органика
#
# [3797044 rows x 131 columns]

# %%
# --- фильтрация по нужным датам ---
dates = ['23.10.2025', '22.10.2025', '21.10.2025', '20.10.2025']
df_filtered = df[df['Дата'].isin(dates)]

# --- группировка и агрегация ---
df_result = (
    df_filtered
    .groupby('Дата', as_index=False)
    .agg({
        'КолвоЗаказанных_распред': 'sum',
        'СуммаЗаказов_распред': 'sum'
    })
    .rename(columns={
        'КолвоЗаказанных_распред': 'CountOrdered',
        'СуммаЗаказов_распред': 'SummaryOrdered'
    })
)

print(df_result)
# Out:
#          Дата  CountOrdered  SummaryOrdered
# 0  20.10.2025         59070     157828105.0
# 1  21.10.2025         52311     137851207.0
# 2  22.10.2025         56212     145360919.0
# 3  23.10.2025         36014      91923647.0

# %%
df[df['Дата']=="2025-10-22"]
# Out:
# Empty DataFrame
# Columns: [Дата, Артикул WB, Рейтинг карточки, Показы, Показы на карточке товара, Положили в корзину, Заказали, шт, Выкупили, шт, Отменили, шт, Заказали на сумму, руб, Выкупили на сумму, руб, Отменили на сумму, руб, Средняя цена, руб, Рейтинг по отзывам, Артикул, Наименование, Коллекция, Бренд, Сезон, Направление, Розничный отдел, Модель, Группа, Бизнес-группа, Техсегмент, Байер, Две последние коллекции, Основной артикул, Себестоимость с НДС, Процент выкупа ВБ, НДС, Ответственный за группу, Группа для отчетов, Тип активности, Автоматическое_ID кампании, Автоматическое_Расход, руб, Автоматическое_Рекламные Заказы, шт, Автоматическое_Рекламные в корзину, Автоматическое_Рекламные заказаных товаров, шт, Автоматическое_Рекламные заказов на сумму, Автоматическое_Рекламные клики, Автоматическое_Рекламные показы, Аукцион_ID кампании, Аукцион_Расход, руб, Аукцион_Рекламные Заказы, шт, Аукцион_Рекламные в корзину, Аукцион_Рекламные заказаных товаров, шт, Аукцион_Рекламные заказов на сумму, Аукцион_Рекламные клики, Аукцион_Рекламные показы, Рекламные показы, Рекламные заказов на сумму, Рекламные Заказы, шт, Рекламные клики, Рекламные в корзину, Рекламные заказаных товаров, шт, Расход, руб, Автоматическое, Аукцион, Цена, Остаток Агрегатора, Дистрибуция, Показы из выгрузки, Клики из выгрузки, Корзины из выгрузки, Заказы из выгрузки, Признак Артикула 1, Признак Артикула 2, Признак Артикула 3, Признак Артикула 4, Признак Артикула 5, Признак Даты 1, Признак Даты 2, Признак Даты 3, Признак Даты 4, Признак Даты 5, Текущая склейка]
# Index: []
#
# [0 rows x 77 columns]

# %%
print(list(df.columns))
# Out:
# ['Дата', 'Артикул', 'Артикул OZ', 'Наименование', 'Коллекция', 'Бренд', 'Сезон', 'Направление', 'Розничный отдел', 'Модель', 'Группа', 'Бизнес-группа', 'Техсегмент', 'Байер', 'Две последние коллекции', 'Основной артикул', 'Себестоимость с НДС', 'Процент выкупа', 'НДС', 'Ответственный за группу', 'Группа для отчетов', 'ID кампании', 'Инструмент', 'Место размещения', 'Вывод в топ', 'Трафарет', 'Оплата за заказ', 'Органика', 'Вывод в топ_Показы, всего', 'Трафарет_Показы, всего', 'Оплата за заказ_Показы, всего', 'Органика_Показы, всего', 'Показы, всего', 'Вывод в топ_Показы на карточке товара', 'Трафарет_Показы на карточке товара', 'Оплата за заказ_Показы на карточке товара', 'Органика_Показы на карточке товара', 'Показы на карточке товара', 'Вывод в топ_Показы в поиске и каталоге', 'Трафарет_Показы в поиске и каталоге', 'Оплата за заказ_Показы в поиске и каталоге', 'Органика_Показы в поиске и каталоге', 'Показы в поиске и каталоге', 'Вывод в топ_Позиция в поиске и каталоге', 'Трафарет_Позиция в поиске и каталоге', 'Оплата за заказ_Позиция в поиске и каталоге', 'Органика_Позиция в поиске и каталоге', 'Позиция в поиске и каталоге', 'Вывод в топ_В корзину, всего', 'Трафарет_В корзину, всего', 'Оплата за заказ_В корзину, всего', 'Органика_В корзину, всего', 'В корзину, всего', 'Вывод в топ_Заказано товаров', 'Трафарет_Заказано товаров', 'Оплата за заказ_Заказано товаров', 'Органика_Заказано товаров', 'Заказано товаров', 'Вывод в топ_Отменено товаров', 'Трафарет_Отменено товаров', 'Оплата за заказ_Отменено товаров', 'Органика_Отменено товаров', 'Отменено товаров', 'Вывод в топ_Доставлено товаров', 'Трафарет_Доставлено товаров', 'Оплата за заказ_Доставлено товаров', 'Органика_Доставлено товаров', 'Доставлено товаров', 'Вывод в топ_Возвращено товаров', 'Трафарет_Возвращено товаров', 'Оплата за заказ_Возвращено товаров', 'Органика_Возвращено товаров', 'Возвращено товаров', 'Вывод в топ_Заказано на сумму', 'Трафарет_Заказано на сумму', 'Оплата за заказ_Заказано на сумму', 'Органика_Заказано на сумму', 'Заказано на сумму', 'Вывод в топ_В корзину из карточки товара', 'Трафарет_В корзину из карточки товара', 'Оплата за заказ_В корзину из карточки товара', 'Органика_В корзину из карточки товара', 'В корзину из карточки товара', 'Вывод в топ_Выкупили ШТ', 'Трафарет_Выкупили ШТ', 'Оплата за заказ_Выкупили ШТ', 'Органика_Выкупили ШТ', 'Выкупили ШТ', 'Вывод в топ_Расход, ₽', 'Трафарет_Расход, ₽', 'Оплата за заказ_Расход, ₽', 'Органика_Расход, ₽', 'Расход, ₽', 'Вывод в топ_Рекламные заказано на сумму', 'Трафарет_Рекламные заказано на сумму', 'Оплата за заказ_Рекламные заказано на сумму', 'Органика_Рекламные заказано на сумму', 'Рекламные заказано на сумму', 'Вывод в топ_Рекламные заказано товаров', 'Трафарет_Рекламные заказано товаров', 'Оплата за заказ_Рекламные заказано товаров', 'Органика_Рекламные заказано товаров', 'Рекламные заказано товаров', 'Вывод в топ_Рекламные показы', 'Трафарет_Рекламные показы', 'Оплата за заказ_Рекламные показы', 'Органика_Рекламные показы', 'Рекламные показы', 'Вывод в топ_Рекламные показы на карточке товара', 'Трафарет_Рекламные показы на карточке товара', 'Оплата за заказ_Рекламные показы на карточке товара', 'Органика_Рекламные показы на карточке товара', 'Рекламные показы на карточке товара', 'Вывод в топ_Цена', 'Трафарет_Цена', 'Оплата за заказ_Цена', 'Органика_Цена', 'Цена', 'Остаток Агрегатора', 'Дистрибуция', 'Признак Артикула 1', 'Признак Артикула 2', 'Признак Артикула 3', 'Признак Артикула 4', 'Признак Артикула 5', 'Признак Даты 1', 'Признак Даты 2', 'Признак Даты 3', 'Признак Даты 4', 'Признак Даты 5', 'ТипАктивности', 'Текущая склейка']

# %%
# Органика
mask = (
    ((df['Расход, ₽'] == 0) | 
     (df['Расход, ₽'] == 0.0))
)
df.loc[mask, 'ТипАктивности'] = 'Органика'

# %%
df[((df['Расход, ₽'] == 0) & (df['ТипАктивности'] == "Трафарет"))][['Артикул', "Дата", "Артикул OZ", "ТипАктивности", "Инструмент","Расход, ₽"]]
# Out:
# Empty DataFrame
# Columns: [Артикул, Дата, Артикул OZ, ТипАктивности, Инструмент, Расход, ₽]
# Index: []

# %%
# Сохранение финальной таблицы
df.to_csv(os.path.join(FOLDER_PATH, "ДБсПризнаками_Ozon.csv"), index=False)
